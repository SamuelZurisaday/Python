# %%
print("123")
print(type("123123"))
print(type(4))
print(len("Mi nombre es Samuel"))
# Out:
# 123
# <class 'str'>
# <class 'int'>
# 19

# %%
#Definir expecto_patronum
def expecto_patronum():
    print("Lobo") #indentacion

expecto_patronum()
# Out:
# Lobo
