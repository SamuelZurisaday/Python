# %%
# Frodo: 116544324
# Drogo: 123132132
agenda = ["No existe"] * 10
agenda[5] = 116544324
agenda[3] = 123132132

# %%
print(agenda)

#Consultar el telefono de Frodo
print("El telefono de Frodo es: ", agenda[5])

#Consultar el telefono de Frodo
print("El telefono de Drogo es: ", agenda[3])

#Consultar el telefono de Frodo
print("El telefono de Kili es: ", agenda[1])
# Out:
# ['No existe', 'No existe', 'No existe', 123132132, 'No existe', 116544324, 'No existe', 'No existe', 'No existe', 'No existe']
# El telefono de Frodo es:  116544324
# El telefono de Drogo es:  123132132
# El telefono de Kili es:  No existe
